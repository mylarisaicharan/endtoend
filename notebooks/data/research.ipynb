# %%
#ingestion of data
import pandas as pd

# %%
data=pd.read_csv(r"C:\endtoend\notebooks\data\gemstone.csv")

# %%
data
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 0            0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33
# 1            1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12
# 2            2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73
# 3            3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41
# 4            4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61
# ...        ...    ...        ...   ...     ...    ...    ...   ...   ...
# 193568  193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39
# 193569  193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77
# 193570  193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75
# 193571  193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49
# 193572  193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71
#
#            z  price
# 0       4.55  13619
# 1       5.05  13387
# 2       3.50   2772
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
data.drop(labels=["id"],axis=1)  #axis =1 means column
# Out:
#         carat        cut color clarity  depth  table     x     y     z  price
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67   1130
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47   2874
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62   3036
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81    681
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48   2258
#
# [193573 rows x 10 columns]

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (193573, 11)

# %%
#saperate categorical and numerical data
categorical_columns=data.columns[data.dtypes=="object"]
numerical_columns=data.columns[data.dtypes!="object"]

# %%
data[categorical_columns].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
data[numerical_columns].describe().T
# Out:
#           count          mean           std    min       25%       50%  \
# id     193573.0  96786.000000  55879.856166    0.0  48393.00  96786.00
# carat  193573.0      0.790688      0.462688    0.2      0.40      0.70
# depth  193573.0     61.820574      1.081704   52.1     61.30     61.90
# table  193573.0     57.227675      1.918844   49.0     56.00     57.00
# x      193573.0      5.715312      1.109422    0.0      4.70      5.70
# y      193573.0      5.720094      1.102333    0.0      4.71      5.72
# z      193573.0      3.534246      0.688922    0.0      2.90      3.53
# price  193573.0   3969.155414   4034.374138  326.0    951.00   2401.00
#
#              75%        max
# id     145179.00  193572.00
# carat       1.03       3.50
# depth      62.40      71.60
# table      58.00      79.00
# x           6.51       9.65
# y           6.51      10.01
# z           4.03      31.30
# price    5408.00   18818.00

# %%
data[categorical_columns]["cut"].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
data[categorical_columns]["color"].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(3,3))

for col in numerical_columns:
    sns.histplot(data=data,x=col,kde=True)
    print("\n")
    
    plt.show()
# Out:
# c:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
plt.figure(figsize=(3,3))

for col in categorical_columns:
    sns.histplot(data=data,x=col,kde=True)
    print("\n")
    
    plt.show()
# Out:
# c:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.heatmap(data[numerical_columns].corr(),annot=True)
# Out:
# <Axes: >

# %%
#encoding:to convert categorical data into numerical data
data["clarity"].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
data["cut"].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
data["color"].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
#it is ordinal encoding
cut_map={"Fair":1,"Good":2,"Very Good":3,"Premium":4,"Ideal":5}
clarity_map={"I1":1,"SI2":2,"SI1":3,"VS2":4,"VS1":5,"VVS2":6,"VVS1":7,"IF":8}
color_map={"D":1,"E":2,"F":3,"G":4,"H":5,"I":6,"J":7}

# %%
data["cut"]==data["cut"].map(cut_map)
data["clarity"]=data["clarity"].map(clarity_map)
data["color"]=data["color"].map(color_map)

# %%
data["cut"]
# Out:
# 0           Premium
# 1         Very Good
# 2             Ideal
# 3             Ideal
# 4           Premium
#             ...
# 193568        Ideal
# 193569      Premium
# 193570    Very Good
# 193571    Very Good
# 193572         Good
# Name: cut, Length: 193573, dtype: object

# %%
data.head()
# Out:
#    id  carat        cut  color  clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium      3        4   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good      7        2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal      4        5   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal      4        5   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium      4        4   62.6   59.0  7.65  7.61  4.77  14453

# %%
#dropping id column
data.drop(labels="id",axis=1,inplace=True)

# %%
data
# Out:
#         carat        cut  color  clarity  depth  table     x     y     z  \
# 0        1.52    Premium      3        4   62.2   58.0  7.27  7.33  4.55
# 1        2.03  Very Good      7        2   62.0   58.0  8.06  8.12  5.05
# 2        0.70      Ideal      4        5   61.2   57.0  5.69  5.73  3.50
# 3        0.32      Ideal      4        5   61.6   56.0  4.38  4.41  2.71
# 4        1.70    Premium      4        4   62.6   59.0  7.65  7.61  4.77
# ...       ...        ...    ...      ...    ...    ...   ...   ...   ...
# 193568   0.31      Ideal      1        6   61.1   56.0  4.35  4.39  2.67
# 193569   0.70    Premium      4        6   60.3   58.0  5.75  5.77  3.47
# 193570   0.73  Very Good      3        3   63.1   57.0  5.72  5.75  3.62
# 193571   0.34  Very Good      1        3   62.9   55.0  4.45  4.49  2.81
# 193572   0.71       Good      2        2   60.8   64.0  5.73  5.71  3.48
#
#         price
# 0       13619
# 1       13387
# 2        2772
# 3         666
# ...
